# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Yasshita

# %% [markdown]
# <i> I am interested in data science because, I believe data is an extremely powerful resource that aids problem solving with high efficiency.

# %% [markdown]
# ### The following code will generate a random integer between 10 and 50

# %%
import random

Random_int = random.randint(10,50)

print(Random_int)
# Out:
# 36

# %% [markdown]
# Projects I would be interested in:

# %% [markdown]
# 1. Football analysis
# 3. Stock market prediction
# 5. Weather prediction

# %% [markdown]
# [Likedin profile](www.linkedin.com/in/yasshita-477517206)

# %% [markdown]
# ![jupyter_logo.jpg](attachment:jupyter_logo.jpg)
